# %%
import os
import pickle

# %%
PATH = os.getcwd()
print(PATH)
# Out:
# /Users/adv/Programming/bgg_recs/ml

# %%
MODEL_PATH = PATH + '/pkl_objects/'
MODEL = MODEL_PATH + 'simple_svd.pkl'

# %%
model = pickle.load(open(MODEL, 'rb'))

# %%
model

# %%
model.trainset._raw2inner_id_users
# Out:
# {'Abso': 0,
#  'Bobby4th': 1,
#  'Gregarius': 2,
#  'kalendrys': 3,
#  'adamdynris': 4,
#  'ZargonDDG': 5,
#  'farchamb': 6,
#  'ChrB': 7,
#  'MarkEJohnson': 8,
#  'Dharquen': 9,
#  'wkover': 10,
#  'calandale': 11,
#  'johnweldy': 12,
#  'Neil Thomson': 13,
#  'Takezo Qc': 14,
#  'tiberiusdw': 15,
#  'gamemark': 16,
#  'Ternal2': 17,
#  'Tr0llet': 18,
#  'Scortez': 19,
#  'Olafslomp': 20,
#  'maxvigne': 21,
#  'bobgabriels1': 22,
#  'dimarco70': 23,
#  'Gyges': 24,
#  'johnwong882': 25,
#  'Ajax': 26,
#  'boxoftricks_13': 27,
#  'gorende': 28,
#  'HaiKulture': 29,
#  'pitonowie': 30,
#  'Stephan Valkyser': 31,
#  'The Gamester': 32,
#  'Lord_Prussian': 33,
#  'tilouboy': 34,
#  'Maeve_1981': 35,
#  'mrquackers': 36,
#  'peacmyer': 37,
#  'punkin312': 38,
#  'ssmooth': 39,
#  'Salamon': 40,
#  'JasonSaastad': 41,
#  'arsior': 42,
#  'dixijo': 43,
#  'OldAgeGamer': 44,
#  'shumyum': 45,
#  'Comrade_Sarayev': 46,
#  'akaisamurai001': 47,
#  'BlueTorch': 48,
#  'lililice': 49,
# ...

# %%
model.predict('broggi','7 Wonders')
# Out:
# Prediction(uid='broggi', iid='7 Wonders', r_ui=None, est=7.859247712912911, details={'was_impossible': False})

# %%
model.trainset._raw2inner_id_items['7 Wonders']
# Out:
# 1516
